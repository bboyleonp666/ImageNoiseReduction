# %%
import cv2
import os
import glob

import numpy as np
import matplotlib.pyplot as plt

# %%
# os.listdir()
# glob.glob("*.jpg")

img = cv2.imread("IMG_20200119_062202.jpg", cv2.IMREAD_GRAYSCALE)

# %%
img
# Out:
# array([[204, 198, 191, ..., 175, 181, 170],
#        [204, 204, 193, ..., 177, 172, 187],
#        [194, 206, 193, ..., 159, 179, 183],
#        ...,
#        [ 41,  40,  40, ...,  32,  18,  19],
#        [ 32,  50,  62, ...,  45,  24,  46],
#        [ 43,  51,  50, ...,  41,  15,  34]], dtype=uint8)

# %%
print("The shape of this image is {}".format(img.shape))
plt.figure(figsize=(10, 10))
plt.imshow(img, cmap="gray")
# Out:
# The shape of this image is (3024, 4032)

# %%
# img.ndim
# np.random.randint()

img_sz = img.shape[0] * img.shape[1]
noise10_sz = np.int(img_sz * .1)
noise20_sz = np.int(img_sz * .2)
noise30_sz = np.int(img_sz * .3)

# %%
noise10 = np.random.randint(img_sz, size=noise10_sz)

# %%
def salt_and_pepper(image, p):
    shape = image.shape
    img_sz = shape[0] * shape[1]
    noise_sz = np.int(img_sz * p)
    
    # sample random noise
    noise = np.random.randint(img_sz, size=noise_sz)
#     salt_or_pepper = np.random.randint(1, size=noise_sz) * 255
    salt = np.repeat(255, noise_sz)
    x = noise % img.shape[0]
    y = noise // img.shape[0]
    
    new_img = image.copy()
#     new_img[x, y] = salt_or_pepper
    new_img[x, y] = salt
    
    return new_img

# %%
img10 = salt_and_pepper(img, .1)

plt.figure(figsize=(10, 10))
plt.imshow(img10, cmap="gray")

# %%
img10
# Out:
# array([[204, 198, 255, ..., 175, 181, 170],
#        [204, 204, 193, ..., 177, 172, 187],
#        [194, 206, 193, ..., 159, 179, 183],
#        ...,
#        [ 41,  40,  40, ...,  32, 255,  19],
#        [ 32,  50,  62, ...,  45,  24,  46],
#        [ 43,  51,  50, ...,  41,  15, 255]], dtype=uint8)

# %%
img20 = salt_and_pepper(img, .2)

plt.figure(figsize=(10, 10))
plt.imshow(img20, cmap="gray")

# %%
img30 = salt_and_pepper(img, .3)

plt.figure(figsize=(10, 10))
plt.imshow(img30, cmap="gray")

# %%
def filters(arr, method):
    filter_sz = arr.shape[1]
    
    if method == "smooth":
        return np.round(np.sum(arr, axis=1) / filter_sz, 0).astype(np.int)
    elif method == "median":
        return np.median(arr, axis=1)

# %%
def denoise(image, mask_sz, method, pad):
    pad_sz = mask_sz // 2
    img_pad = np.pad(image, (pad_sz, pad_sz), mode=pad)
    col_len = img_pad.shape[1]
    img_pad_flat = img_pad.flatten()
    
    tmp_arr = np.arange(mask_sz) * col_len
    mask = np.repeat(tmp_arr, mask_sz) + np.tile(range(mask_sz), mask_sz)
    i = np.repeat(range(image.size), mask_sz**2)
    index = np.tile(mask, img10.size) + i
    
    kernelInfo = img_pad_flat[index]
    kernelInfo.shape = (kernelInfo.size // mask_sz**2, mask_sz**2)
    imgInfo = filters(kernelInfo, method)
    return np.reshape(imgInfo, image.shape)

# %%
tmp = np.random.randint(100, size=10)
# tmp[[1, 2, 3, 1, 2, 3, 1, 2, 3]]
mask_sz = 3
i = np.repeat(range(img10.size), mask_sz**2)

pad_sz = mask_sz // 2
img_pad = np.pad(img10, (pad_sz, pad_sz), mode="reflect")
col_len = img_pad.shape[1]
tmp_arr = np.arange(mask_sz) * col_len
mask = np.repeat(tmp_arr, mask_sz) + np.tile(range(mask_sz), mask_sz)

# %%
index = np.tile(mask, img10.size) + i

img_pad_flat = img_pad.flatten()
kernelInfo = img_pad_flat[index]
kernelInfo.shape = (kernelInfo.size // mask_sz**2, mask_sz**2)

kernelInfo.shape
# Out:
# (12192768, 9)

# %%
img10_dnoise = denoise(img10, 3, "smooth", "reflect")
plt.figure(figsize=(10, 10))
plt.imshow(img10_dnoise, cmap="gray")

# %%
img10_dnoise = denoise(img10, 3, "median", "reflect")
plt.figure(figsize=(10, 10))
plt.imshow(img10_dnoise, cmap="gray")

# %%
mask_sz = 3
mask = np.ones((mask_sz, mask_sz), np.float32)/ (mask_sz ** 2)

# 將 mask apply 到原始圖像做 Smoothing
smoothing_img = cv2.filter2D(img10, -1, mask)

# %%
plt.imshow(smoothing_img, cmap="gray")
